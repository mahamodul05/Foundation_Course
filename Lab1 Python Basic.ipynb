# %%
print("Welcome to AI Lab")
# Out:
# Welcome to AI Lab

# %% [markdown]
# # Python Programming Language
# 1. Data types and variables
#    > int
#
#    > float
#
#    > bool
#
#    > string
#
#    > ADT : List, Tupple, Dictionay, Set
#
#
# 3. operator and expression
#    > Arithematic Operator: +,-,*,/,//,**,%
#
#    > Relational Opeartor : >, >=,<,<=,==,!=
#
#    > Logical Operator: & (and), | (or)
# 5. conditional statement
#     > if
#     >
#     > if else
#     >
#     > if elif ..... else
# 7. Iteration
#    > for
#    >
#    > range
#    >
#    > while
#    >
#    > break
#    >
#    > continue
# 9. Function and List
# 10. python Library
# 11. OOP

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
c=True
print(c)
print(type(c))
# Out:
# True
# <class 'bool'>

# %%
b=3.9
print(b)
print(type(b))
# Out:
# 3.9
# <class 'float'>

# %%
s1="I love AI"
print(s1)
print(type(s1))
# Out:
# I love AI
# <class 'str'>

# %%
s = [1,2,3,4,5]

# %%
s[2:5]

# %%
print(s1[3])
print(s1[2:6]) # index slicing

# %%
print(len(s1))

# %%
s1="I love Python\n"
s2="I love Bangladesh"
print(s1+s2)

# %%
'''
Line 1
Line 2
'''
a=10
b=20
print(a+b)
print(a-b)
print(a*b)
print(a/b) # floating point division
print(a//b) # integer division
print(a**2)
print(a%b)

# %%
a=10
b=20
print(a>b)
print(a>=b)
print(a<b)
print(a<=b)
print(a==b)
print(a!=b)

# %%
a=10
b=20
c=2
print((a>b) and (a>c))
print((a>b) or (a>c))

# %%
a=20
if a>10:
    print("a is gerater than 10")
    print("I love python")
print("I love Bangladesh")

# %%
age=20
if age>=18:
    print("I am adult")
else:
    print("I am not adult")

# %%
marks =90
if marks>=90:
    print("A+")
elif marks>=85 and marks<90:
    print("A")
else:
    print("F")

# %%
number1=input("Enter number 1: ")
number2=input("Enter Number 2: ")
print(int(number1)+int(number2)) # type casting

# %%
a=input("Enter CGPA:")
print(float(a))

# %%
for i in range(10):
    print(i,end=" ")

# %%
for i in range(2,10):
    print(i,end=" ")

# %%
for i in range(10,100,2):
    print(i,end=" ")

# %%
s1="I love python and I love AI"
n=len(s1)
for i in range(0,n,3):
    print(s1[i])

# %%
i=0
while i<10:
    print(i)
    i=i+1

# %%
for i in range(1,11):
    if i==6:
        break
    print(i, end="->")

# %%
for i in range(1,11):
    if i==6 or i==9:
        continue
    print(i, end="->")
